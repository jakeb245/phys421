# %%
import numpy as np
import matplotlib.pyplot as plt

import random

import time

# %%
# define a generator function for the polynomial
def generator_function(x,*par):
    return par[0]+par[1]*x+par[2]*x*x+par[3]*x*x*x

# %%
def find_roots(window,n_roots_expected):
    
    xroots = []
    yroots = []

    n_roots_found = 0

    n = 0

    while (n_roots_found < n_roots_expected):

        diff = 1.0E12
        epsilon = 1.0E-7

        xc = np.random.uniform(xl,xh)
        xa = xc - window/2.0
        xb = xc + window/2.0

        fa = generator_function(xa,*par)
        fb = generator_function(xb,*par)

        #print (xc,xa,xb,fa,fb)

        if (fa*fb > 0):
            #print ('here 1')
            n += 1
        else:
            #print ('here 2')
            while (diff > epsilon and n<10000):
                xc = (xb-xa)/2.0+xa
                fc = generator_function(xc,*par)
    
                if (fa*fc < 0):
                    xb = xc
                    fb = generator_function(xb,*par)
                    diff = np.abs(fc-fa)
                else:
                    xa = xc
                    fa = generator_function(xa,*par)
                    diff = np.abs(fc-fb)
            
                n += 1

            already_found = False
            if n_roots_found > 0:
                for xroot in xroots:
                    if (np.fabs(xroot-xc) < 5.0*epsilon):
                        already_found = True
            
            if (not already_found):
                n_roots_found += 1
                xroots.append(xc)
                yroots.append(fc)
    
    return n,xroots,yroots

# %%
# Set the x limits, and the number of points, calculate the interval, and set the function parameters
xl = -4.0
xh = 4.0
npoints = 10000

dx = (xh-xl)/npoints

par = np.array([1.80,-4.05,0.4,1.0])

# Find the roots!!!!!!!!!
n, xroots, yroots = find_roots(0.5,3)
print (n,xroots,yroots)

# Generate the figure and the axes 
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(9,9))

xval = np.arange(xl,xh,dx)
yval = generator_function(xval,*par)

# On the first axis, plot the sine and label the ordinate 
axs.plot(xval,yval)
axs.scatter(xroots,yroots)
axs.set_ylabel('Y Value')
axs.set_xlabel('X Value')
axs.axhline()
plt.show()
# Out:
# 108 [1.500000007784335, -2.4000000073188374, 0.4999999987688506] [3.0358906055738544e-08, -8.27760526789234e-08, 3.570333362290512e-09]

# %%
xwin = []
nwin = []

for i in range(100):
    window = 0.001 + i/100.0*0.5
    n,xroots,yroots = find_roots(window,3)
    xwin.append(window)
    nwin.append(n)
    
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(9,9))
plt.plot(xwin,nwin,'.')

# %%
nstat = []

for i in range(1000):
    n,xroots,yroots = find_roots(1.0,3)
    nstat.append(n)
    
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(9,9))
counts, bins = np.histogram(nstat)
plt.hist(bins[:-1], bins, weights=counts)

nstat = np.array(nstat)

print (nstat.mean(),nstat.mean()/npoints)
# Out:
# 151.949 0.0151949

# %%
# Set the x limits, and the number of points, and calculate the interval
xl = -4.0
xh = 4.0
npoints = 1000

dx = (xh-xl)/npoints

par = np.array([1.80,-4.05,0.4,1.0])

nstat = []

for i in range(1000):
    n,xroots,yroots = find_roots(1.0,3)
    nstat.append(n)

fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(12,12))
counts, bins = np.histogram(nstat)
plt.hist(bins[:-1], bins, weights=counts)

nstat = np.array(nstat)

print (nstat.mean(),nstat.mean()/npoints)
# Out:
# 155.351 0.155351
